# %%
import matplotlib.pyplot as plt 
import pandas as pd

# %%
base_dir = f'../all_approx/base_sine/base-sine/test.csv'
app_1_dir = f'../all_approx/approx_1/Approximation1/test.csv'
app_2_dir = f'../all_approx/approx_2/Approximation2/test.csv'

# %%
base_df = pd.read_csv(base_dir)
app1_df = pd.read_csv(app_1_dir)
app2_df = pd.read_csv(app_2_dir)

# %% [markdown]
# ### Base Sine Signal Plot
#
# ### Details
#
# generated-timeseries:
#
# base-oscillations:
#   - amplitude: 1.1
#   - frequency: 4.0
#   - kind: sine
#   - variance: 0.05
#   - length: 1000

# %%
plt.figure(figsize=(10, 6))

plt.plot(base_df['timestamp'], base_df['value-0'], label = 'Base Signal')
plt.xlabel('Time Stamp')
plt.ylabel('Amplitude')
plt.title('Base Sine Signal')
plt.show()

# %% [markdown]
# ### 1st Approximation Plot
#
# ### Details
#
#  * base-oscillations:
#    - kind: sine
#    - frequency: 4.0
#    - amplitude: 1.1
#    - variance: 0.05
#  * anomalies:
#    - exact-position: 0
#    - length: 100
#    - kind: frequency
#       - frequency_factor: 1.1
#
#    - position: middle
#      - length: 200
#      - kind: mean
#         - offset: 0.257

# %%
plt.figure(figsize=(10, 6))

plt.plot(app1_df['timestamp'], app1_df['value-0'], label = 'Approximation 1 Signal')
plt.xlabel('Time Stamp')
plt.ylabel('Amplitude')
plt.title('Approximation 1 Signal')
plt.show()

# %% [markdown]
# ### Approximation 2 Plots
#
# ### Details
#
# * base-oscillations:
#   - kind: sine
#   - frequency: 4.0
#   - amplitude: 1.1
#   - variance: 0.05
# * anomalies:
#   - exact-position: 0
#   - length: 400
#   - kind: pattern
#     sinusoid_k: 1.1

# %%
plt.figure(figsize=(10, 6))

plt.plot(app2_df['timestamp'], app2_df['value-0'], label = 'Approximation 2 Signal')
plt.xlabel('Time Stamp')
plt.ylabel('Amplitude')
plt.title('Approximation 2 Signal')
plt.show()
